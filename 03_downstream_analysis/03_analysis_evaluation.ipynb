# %% [markdown]
# # Notebook to evaluate the CellPainting protocol

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import string
from matplotlib.patches import Patch
from matplotlib.colors import ListedColormap, BoundaryNorm, Normalize
from matplotlib.colors import to_hex

# %%
df_level4b = pd.read_csv("../02_processed_data/df_level4b.csv")

# %%
# Ensure 'Metadata_Well' is a string
df_level4b["Metadata_Well"] = df_level4b["Metadata_Well"].astype(str)

# Extract row (letter(s)) and column (numbers))
df_level4b["Metadata_row"] = df_level4b["Metadata_Well"].str.extract(r"^([A-Z]+)")
df_level4b["Metadata_col"] = df_level4b["Metadata_Well"].str.extract(r"(\d+)$").astype(int)

# Convert row letters (A→1, B→2, etc.)
row_map = {letter: idx for idx, letter in enumerate(string.ascii_uppercase, start=1)}
df_level4b["Metadata_row"] = df_level4b["Metadata_row"].map(row_map)
# Compute a column with unique id column
df_level4b["Metadata_Source_Plate_Well"] = (
        df_level4b["Metadata_Source"].astype(str) + "_" +
        df_level4b["Metadata_Plate"].astype(str) + "_" +
        df_level4b["Metadata_Well"].astype(str)
    )

# %% [markdown]
# # Evaluate replicats

# %%
# Replicates per plates 
plates = df_level4b["Metadata_Plate"].unique()
for _plate in plates:
    n_chem_rep_plate = sum(df_level4b[df_level4b["Metadata_Plate"] == _plate][["Metadata_JCP2022"]].value_counts().to_frame()['count'] > 1)
    n_chem_no_rep_plate = sum(df_level4b[df_level4b["Metadata_Plate"] == _plate][["Metadata_JCP2022"]].value_counts().to_frame()['count'] == 1)
    print("In plate ", _plate,", there are :", n_chem_rep_plate, "chemicals that have replicates")
    print("In plate ", _plate,", there are :", n_chem_no_rep_plate, "chemicals that don't have replicates")
# Out:
# In plate  BR00127145 , there are : 20 chemicals that have replicates
# In plate  BR00127145 , there are : 282 chemicals that don't have replicates
# In plate  BR00127146 , there are : 20 chemicals that have replicates
# In plate  BR00127146 , there are : 282 chemicals that don't have replicates
# In plate  BR00127147 , there are : 19 chemicals that have replicates
# In plate  BR00127147 , there are : 282 chemicals that don't have replicates
# In plate  BR00127148 , there are : 20 chemicals that have replicates
# In plate  BR00127148 , there are : 282 chemicals that don't have replicates
# In plate  BR00127149 , there are : 20 chemicals that have replicates
# In plate  BR00127149 , there are : 282 chemicals that don't have replicates

# %%
# Replicates per plate per chemical
plates = df_level4b["Metadata_Plate"].unique()
chemicals = df_level4b["Metadata_JCP2022"].unique()
for _plate in plates:
    for _chemical in chemicals:
        n_chem_rep = df_level4b[
            (df_level4b["Metadata_Plate"] == _plate) &
            (df_level4b["Metadata_JCP2022"] == _chemical)
        ]
        print(f"Plate: {_plate}, Chemical: {_chemical}, Replicates: {len(n_chem_rep)}")
# Out:
# Plate: BR00127145, Chemical: JCP2022_043547, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_050797, Replicates: 2
# Plate: BR00127145, Chemical: JCP2022_050997, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_108326, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_033924, Replicates: 64
# Plate: BR00127145, Chemical: JCP2022_027911, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_100264, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_050861, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_014367, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_071429, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_016288, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_091373, Replicates: 2
# Plate: BR00127145, Chemical: JCP2022_004940, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_103217, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_079562, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_020163, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_099471, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_048971, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_060649, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_061421, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_030713, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_042261, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_113600, Replicates: 1
# Plate: BR00127145, Chemical: JCP2022_001890, Replicates: 2
# Plate: BR00127145, Chemical: JCP2022
Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_001036, Replicates: 2
# Plate: BR00127149, Chemical: JCP2022_043332, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_077671, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_021751, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_064903, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_069668, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_017377, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_097564, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_107658, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_093901, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_081496, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_073458, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_065525, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_076300, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_059269, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_002118, Replicates: 2
# Plate: BR00127149, Chemical: JCP2022_106680, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_041139, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_043287, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_058461, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_081555, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_062592, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_007175, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_055904, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_003951, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_094002, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_087562, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_078581, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_046649, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_001275, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_035351, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_035570, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_052259, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_039116, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_086505, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_090884, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_093047, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_053626, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_099089, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_009419, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_022191, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_078588, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_018074, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_077046, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_035095, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_039047, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_074702, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_045105, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_114461, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_044972, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_077927, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_087693, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_059825, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_033012, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_062184, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_067426, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_100876, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_059103, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_092256, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_084364, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_009867, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_034137, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_083372, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_077142, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_097998, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_062023, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_050162, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_060311, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_085892, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_010654, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_090768, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_112828, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_030831, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_075916, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_068634, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_096067, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_032357, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_047545, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_043099, Replicates: 1
# Plate: BR00127149, Chemical: JCP2022_050516, Replicates: 1

# %%
for _plate in plates:
    n_dmso = sum(df_level4b[df_level4b["Metadata_Plate"] == _plate]["Metadata_Name"] == "DMSO")
    print("In plate ", _plate,", there are :", n_dmso, "DMSO out of 384 wells")
# Out:
# In plate  BR00127145 , there are : 64 DMSO out of 384 wells
# In plate  BR00127146 , there are : 64 DMSO out of 384 wells
# In plate  BR00127147 , there are : 64 DMSO out of 384 wells
# In plate  BR00127148 , there are : 64 DMSO out of 384 wells
# In plate  BR00127149 , there are : 64 DMSO out of 384 wells

# %%
chemicals = df_level4b["Metadata_JCP2022"].unique()
for _chemical in chemicals:
    n_chem = len(df_level4b[df_level4b["Metadata_JCP2022"] == _chemical])
    print("For chemical ", _chemical,", there are :", n_chem, "replicates accross the different plates")
# Out:
# For chemical  JCP2022_043547 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_050797 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_050997 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_108326 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_033924 , there are : 320 replicates accross the different plates
# For chemical  JCP2022_027911 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_100264 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_050861 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_014367 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_071429 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_016288 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_091373 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_004940 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_103217 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_079562 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_020163 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_099471 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_048971 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_060649 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_061421 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_030713 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_042261 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_113600 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_001890 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_061654 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_093289 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_115963 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_079617 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_111730 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_067887 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_080150 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_098688 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_012146 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_029951 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_014114 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_021678 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_062326 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_010382 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_061437 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_029365 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_116188 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_047559 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_055397 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_068660 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_030049 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_105456 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_105621 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_067432 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_058046 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_068838 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_087474 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_024601 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_096865 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_042332 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_054601 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_075930 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_018899 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_115049 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_087444 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_113710 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_052804 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_039503 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_093678 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_077089 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_044197 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_109350 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_113779 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_096054 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_007613 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_032771 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_105442 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_018280 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_076573 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_033914 , there are : 9 replicates accross the different plates
# For chemical  JCP2022_005529 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_080920 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_013856 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_096342 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_046054 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_102083 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_104794 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_089172 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_090205 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_016935 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_073156 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_028940 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_073628 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_030094 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_064183 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_033400 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_106722 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_050271 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_020718 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_084963 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_028645 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_074697 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_024824 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_045036 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_092464 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_080224 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_021857 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_048928 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_007419 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_069672 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_085227 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_068238 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_102917 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_050830 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_056401 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_077096 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_006270 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_101929 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_060734 , there are : 4 replicates accross the different plates
# For chemical  JCP2022_033936 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_100688 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_033814 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_063174 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_101857 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_053409 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_052870 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_114322 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_027206 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_089383 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_041253 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_028032 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_081430 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_056730 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_067441 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_046239 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_069285 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_034709 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_069131 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_103291 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_000794 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_112702 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_053734 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_093956 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_041107 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_017914 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_054618 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_076523 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_004587 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_039863 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_104437 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_102936 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_051415 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_079715 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_060040 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_090051 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_025848 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_005163 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_042960 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_022359 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_115134 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_051043 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_083099 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_050338 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_057881 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_049224 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_011759 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_110929 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_012198 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_013455 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_032680 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_088849 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_057163 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_038675 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_029186 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_066287 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_035296 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_015955 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_075182 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_106781 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_046462 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_068713 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_116560 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_071910 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_071733 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_064022 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_032353 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_058889 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_082234 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_116437 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_093480 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_050873 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_029868 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_023781 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_005628 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_057971 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_088224 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_047143 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_009886 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_109917 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_058288 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_075694 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_105696 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_012818 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_106219 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_105539 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_068901 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_010404 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_031861 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_051319 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_002206 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_072945 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_019314 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_038096 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_059966 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_082046 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_069491 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_036614 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_084606 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_116749 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_067886 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_109043 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_026475 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_046524 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_076233 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_037716 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_068606 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_042354 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_071811 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_001036 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_043332 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_077671 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_021751 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_064903 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_069668 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_017377 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_097564 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_107658 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_093901 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_081496 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_073458 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_065525 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_076300 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_059269 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_002118 , there are : 10 replicates accross the different plates
# For chemical  JCP2022_106680 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_041139 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_043287 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_058461 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_081555 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_062592 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_007175 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_055904 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_003951 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_094002 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_087562 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_078581 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_046649 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_001275 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_035351 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_035570 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_052259 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_039116 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_086505 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_090884 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_093047 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_053626 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_099089 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_009419 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_022191 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_078588 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_018074 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_077046 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_035095 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_039047 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_074702 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_045105 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_114461 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_044972 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_077927 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_087693 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_059825 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_033012 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_062184 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_067426 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_100876 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_059103 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_092256 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_084364 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_009867 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_034137 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_083372 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_077142 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_097998 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_062023 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_050162 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_060311 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_085892 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_010654 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_090768 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_112828 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_030831 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_075916 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_068634 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_096067 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_032357 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_047545 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_043099 , there are : 5 replicates accross the different plates
# For chemical  JCP2022_050516 , there are : 5 replicates accross the different plates

# %%
# Count replicates per chemical
replicates = (
    df_level4b.groupby("Metadata_JCP2022")
    .size()
    .reset_index(name="Replicates")
)

# Count how many chemicals have each replicate count
replicate_dist = replicates["Replicates"].value_counts().sort_index()

# --- Plot ---
plt.figure(figsize=(8, 5))
ax = sns.barplot(
    x=replicate_dist.index,
    y=replicate_dist.values,
    color="skyblue"
)

# Add numbers on top of bars
for i, v in enumerate(replicate_dist.values):
    ax.text(i, v + 0.2, str(v), ha='center', va='bottom', fontsize=10)

plt.title("Distribution of Replicate Counts Across Chemicals")
plt.xlabel("Number of Replicates per Chemical")
plt.ylabel("Number of Chemicals")
plt.tight_layout()
plt.show()

# %% [markdown]
# # Analysis experiments

# %%
for _plate, df_plate in df_level4b.groupby("Metadata_Plate"):
    df_plate = df_plate.copy()
    df_plate["is_DMSO"] = df_plate["Metadata_Name"].eq("DMSO")

    # Create column for plotting: chemical name or NaN for DMSO
    df_plate["chem_for_plot"] = np.where(
        df_plate["is_DMSO"], np.nan, df_plate["Metadata_JCP2022"]
    )

    # Unique non-DMSO chemicals
    unique_chems = sorted(df_plate.loc[~df_plate["is_DMSO"], "Metadata_JCP2022"].unique())
    n_chems = len(unique_chems)

    # Pivot for plate layout
    plate_map = (
        df_plate.pivot(index="Metadata_row", columns="Metadata_col", values="chem_for_plot")
        .sort_index()
        .sort_index(axis=1)
    )

    # --- Colormap setup ---
    _cmap = ListedColormap(sns.color_palette("Set2", n_colors=n_chems))

    plt.figure(figsize=(10, 6))

    # --- Draw base map: color by chemical ---
    _color_dict = dict(zip(unique_chems, _cmap.colors))
    _color_dict = {chem: to_hex(color) for chem, color in _color_dict.items()}
    color_grid = plate_map.replace(_color_dict)

    # Replace NaN (DMSO) with gray color
    color_grid = color_grid.fillna("lightgray")

    # --- Plot ---
    _ax = sns.heatmap(
        np.empty_like(color_grid, dtype=float),  # placeholder grid
        annot=plate_map,                        # show chemical names (optional)
        fmt="",
        cbar=False,
        linewidths=0.5,
        linecolor="gray",
    )

    for (r, c), value in np.ndenumerate(plate_map.values):
        color = "lightgray" if pd.isna(value) else _color_dict[value]
        _ax.add_patch(plt.Rectangle((c, r), 1, 1, fill=True, color=color, lw=0))

    # --- Custom legend ---
    #legend_elements = [
    #    Patch(facecolor=color, label=chem) for chem, color in _color_dict.items()
    #]
    #legend_elements.append(Patch(facecolor="lightgray", label="DMSO"))

    #plt.legend(
    #    handles=legend_elements,
    #    title="Chemicals",
    #    bbox_to_anchor=(1.05, 1),
    #    loc="upper left",
    #    borderaxespad=0.,
    #)


    # --- Aesthetic details ---
    plt.title(f"Plate {_plate} — Chemical layout (DMSO in gray)")
    plt.xlabel("Column")
    plt.ylabel("Row")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Analysis GRiT

# %%
df_grit = pd.read_csv("../02_processed_data/grit.csv")

# %%
# Join table metadata
df_grit_annotate = pd.merge(
    df_grit,
    df_level4b,
    left_on=["perturbation"],
    right_on=["Metadata_Source_Plate_Well"],
    how="inner"   # or "left" / "right" / "outer" depending on your need
)

# %%
# Create a common color map
_cmap = sns.color_palette("hls", as_cmap=True)
# Compute global min and max across all data
_vmin = df_grit_annotate["grit"].min()
_vmax = df_grit_annotate["grit"].max()
for _plate, df_plate_grit in df_grit_annotate.groupby("Metadata_Plate"):
    df_plate_grit = df_plate_grit.copy()
    df_plate_grit["grit_for_plot"] = df_plate_grit["grit"]

    # Pivot for heatmap
    plate_map_ldh = (
        df_plate_grit.pivot(
            index="Metadata_row",
            columns="Metadata_col",
            values="grit_for_plot",
        )
        .sort_index()
        .sort_index(axis=1)
    )

    plt.figure(figsize=(10, 6))

    _ax = sns.heatmap(
        plate_map_ldh,
        cmap=_cmap,
        vmin=_vmin,
        vmax=_vmax,
        cbar_kws={"label": "grit"},
        linewidths=0.5,
        linecolor="gray",
    )

    # --- Aesthetic details ---
    plt.title(f"Plate {_plate} — grit")
    plt.xlabel("Column")
    plt.ylabel("Row")
    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Analysis mAP
